# %%
# Download spaces on the Janelia wiki and save to files on disk
# Based on documentation at https://atlassian-python-api.readthedocs.io/confluence.html#get-page-info
#
# To use this notebook, you must create a Personal Access Token and save it into your environment:
# https://wikis.janelia.org/plugins/personalaccesstokens/usertokens.action
#

import os
from atlassian import Confluence

confluence_url = "https://wikis.janelia.org"
confluence_pat = os.environ.get('CONFLUENCE_TOKEN')
confluence = Confluence(url=confluence_url, token=confluence_pat)

space = 'SCSW'
title = 'SAGE'
page_id = confluence.get_page_id(space, title)

print(page_id)
# Out:
# 30746913

# %%
def parse_page(page):
    page_id = int(page['id'])
    path = page['_links']['webui']
    title = page['title']
    body = page['body']['view']['value']
    labels = [l['name'] for l in page['metadata']['labels']['results']]
    ancestors = [p['title'] for p in page['ancestors']]
    createdBy = page['history']['createdBy']['displayName']
    authors = [createdBy]
    if 'lastUpdated' in page['history']:
        lastUpdatedBy = page['history']['lastUpdated']['by']['displayName']
        if lastUpdatedBy != createdBy:
            authors.append(lastUpdatedBy)

    return page_id,path,title,body,labels,ancestors,authors

def get_page(page_id):
    # This only retrieves the createdBy and lastUpdatedBy for history
    page = confluence.get_page_by_id(page_id, expand="body.view,metadata.labels,ancestors,history,history.lastUpdated", status=None, version=None)
    print(page)

    # The history() call also retrieves the createdBy and lastUpdatedBy. There doesn't 
    # appear to be a way to retrieve a list of all versions or all contributors with the API. 
    #history = confluence.history(page_id, expand="contributors")
    #print(history)
    
    return parse_page(page)

def get_link(path):
    return "%s%s" % (confluence_url, path)
    
page_id,path,title,body,labels,ancestors,authors = get_page(page_id)
print("ID:", page_id)
print("Path:", path)
print("Link:", get_link(path))
print("Title:",title)
print("Labels:",labels)
print("Ancestors:",ancestors)
print("Authors:",authors)
print(body)
# Out:
# {'id': '30747611', 'type': 'page', 'status': 'current', 'title': 'Male Brain FIB-SEM Experiments Alignment', 'history': {'lastUpdated': {'by': {'type': 'known', 'username': 'khairyk', 'userKey': '2c9003a481970a02018265b984200061', 'profilePicture': {'path': '/images/icons/profilepics/default.svg', 'width': 48, 'height': 48, 'isDefault': True}, 'displayName': 'Unknown User (khairyk)', '_links': {'self': 'https://wikis.janelia.org/rest/api/user?key=2c9003a481970a02018265b984200061'}, '_expandable': {'status': ''}}, 'when': '2018-01-17T13:07:02.000-05:00', 'message': '', 'number': 34, 'minorEdit': False, 'hidden': False, '_links': {'self': 'https://wikis.janelia.org/rest/experimental/content/30747611/version/34'}, '_expandable': {'content': '/rest/api/content/30747611'}}, 'latest': True, 'createdBy': {'type': 'known', 'username': 'khairyk', 'userKey': '2c9003a481970a02018265b984200061', 'profilePicture': {'path': '/images/icons/profilepics/default.svg', 'width': 48, 'height': 48, 'isDefault': True}, 'displayName': 'Unknown User (khairyk)', '_links': {'self': 'https://wikis.janelia.org/rest/api/user?key=2c9003a481970a02018265b984200061'}, '_expandable': {'status': ''}}, 'createdDate': '2017-09-22T11:22:11.000-04:00', '_links': {'self': 'https://wikis.janelia.org/rest/api/content/30747611/history'}, '_expandable': {'previousVersion': '', 'contributors': '', 'nextVersion': ''}}, 'ancestors': [{'id': '30747457', 'type': 'page', 'status': 'current', 'title': 'Home', 'extensions': {'position': 2}, '_links': {'webui': '/display/ScientificComputing/Home', 'edit': '/pages/resumedraft.action?draftId=30747457', 'tinyui': '/x/QSvVAQ', 'self': 'https://wikis.janelia.org/rest/api/content/30747457'}, '_expandable': {'container': '/rest/api/space/ScientificComputing', 'metadata': '', 'operations': '', 'children': '/rest/api/content/30747457/child', 'restrictions': '/rest/api/content/30747457/restriction/byOperation', 'history': '/rest/api/content/30747457/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/30747457/descendant', 'space': '/rest/api/space/ScientificComputing'}}, {'id': '30746506', 'type': 'page', 'status': 'current', 'title': 'Scientific Computing Software', 'extensions': {'position': 8}, '_links': {'webui': '/display/ScientificComputing/Scientific+Computing+Software', 'edit': '/pages/resumedraft.action?draftId=30746506', 'tinyui': '/x/iifVAQ', 'self': 'https://wikis.janelia.org/rest/api/content/30746506'}, '_expandable': {'container': '/rest/api/space/ScientificComputing', 'metadata': '', 'operations': '', 'children': '/rest/api/content/30746506/child', 'restrictions': '/rest/api/content/30746506/restriction/byOperation', 'history': '/rest/api/content/30746506/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/30746506/descendant', 'space': '/rest/api/space/ScientificComputing'}}, {'id': '30747592', 'type': 'page', 'status': 'current', 'title': 'Computational Methods Group', 'extensions': {'position': 'none'}, '_links': {'webui': '/display/ScientificComputing/Computational+Methods+Group', 'edit': '/pages/resumedraft.action?draftId=30747592', 'tinyui': '/x/yCvVAQ', 'self': 'https://wikis.janelia.org/rest/api/content/30747592'}, '_expandable': {'container': '/rest/api/space/ScientificComputing', 'metadata': '', 'operations': '', 'children': '/rest/api/content/30747592/child', 'restrictions': '/rest/api/content/30747592/restriction/byOperation', 'history': '/rest/api/content/30747592/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/30747592/descendant', 'space': '/rest/api/space/ScientificComputing'}}], 'body': {'view': {'value': '<p>Alignment results are summarized here: /groups/flyem/data/khairy_alignments/alignment_quality_output: Q_* files for pdfs, matlab fig and tif files can be found for rms graphs, and tile deformation metrics.</p><p>\xa0</p><hr/><p>\xa0</p><p><strong>Experiments on D08_09:</strong></p><p>\xa0</p>< ...
# ID: 30747611
# Path: /display/ScientificComputing/Male+Brain+FIB-SEM+Experiments+Alignment
# Link: https://wikis.janelia.org/display/ScientificComputing/Male+Brain+FIB-SEM+Experiments+Alignment
# Title: Male Brain FIB-SEM Experiments Alignment
# Labels: []
# Ancestors: ['Home', 'Scientific Computing Software', 'Computational Methods Group']
# Authors: ['Unknown User (khairyk)']
# <p>Alignment results are summarized here: /groups/flyem/data/khairy_alignments/alignment_quality_output: Q_* files for pdfs, matlab fig and tif files can be found for rms graphs, and tile deformation metrics.</p><p> </p><hr/><p> </p><p><strong>Experiments on D08_09:</strong></p><p> </p><p>point-matches generated using scale 0.4 with optimized filter:</p><p>                                                                translation-only alignment:</p><p>                                                                                                         collection:     <a href="http://renderer-catmaid-2:8000/?tool=navigator&amp;s0=8&amp;pid=flyem_04male_082017&amp;sid0=kk_08_09_trans_pm_0_4_d1_exp1_1295&amp;zp=8&amp;yp=104224&amp;xp=115108" class="external-link" rel="nofollow">kk_08_09_trans_pm_0_4_d1_exp1_1295</a></p><p>                                                                                                      image-stack:       /groups/flyem/data/khairy_alignments/D08_09_ministack/flyem_04male_082017/kk_08_09_trans_pm_0_4_d1_exp1_1295/scape_20171002_165732/000</p><p> </p><p>                                                                Affine alignment:</p><p>                                                                                                         collection:     <a href="http://tem-services.int.janelia.org:8080/render-ws/view/stack-details.html?renderStackOwner=hessh&amp;renderStackProject=flyem_04male_082017&amp;renderStack=kk_08_09_fine_pm_0_4_d1_exp1_1295&amp;dynamicRenderHost=renderer%3A8080&amp;catmaidHost=renderer-catmaid-2%3A8000" class="external-link" rel="nofollow">kk_08_09_fine_pm_0_4_d1_exp1_1295</a></p><p>                                                                                                      image-stack:       /groups/flyem/data/khairy_alignments/D08_09_ministack/flyem_04male_082017/kk_08_09_fine_pm_0_4_d1_exp1_1295/scape_20171002_165800/000</p><p> </p><p> </p><p>point-matches generated using scale 0.4 with standard point-match filter:</p><p>                                                                translation-only alignment:</p><p>                                                                                                         collection:     <a href="http://renderer-catmaid-2:8000/?tool=navigator&amp;s0=8&amp;pid=flyem_04male_082017&amp;sid0=kk_08_09_trans_pm_0_4_d1_1_1295&amp;zp=8&amp;yp=104224&amp;xp=115108" class="external-link" rel="nofollow">kk_08_09_trans_pm_0_4_d1_1_1295</a></p><p>                                                                                                      image-stack:       /groups/flyem/data/khairy_alignments/D08_09_ministack/flyem_04male_082017/kk_08_09_trans_pm_0_4_d1_1_1295/scape_20171002_114144/000</p><p> </p><p>                                                                Affine alignment:</p><p>                                                                                                         collection:     <a href="http://renderer-catmaid-2:8000/?tool=navigator&amp;s0=8&amp;pid=flyem_04male_082017&amp;sid0=kk_08_09_fine_pm_0_4_d1_1_1295&amp;zp=8&amp;yp=104224&amp;xp=115108" class="external-link" rel="nofollow">kk_08_09_fine_pm_0_4_d1_1_1295</a></p><p>                                                                                                      image-stack:       /groups/flyem/data/khairy_alignments/D08_09_ministack/flyem_04male_082017/kk_08_09_fine_pm_0_4_d1_1_1295/scape_20171002_114208/000</p><p> </p><p>point-matches generated using scale 0.7:</p><p>                                                                translation-only alignment:</p><p>                                                                                                         collection:     <a href="http://renderer-catmaid-2:8000/?tool=navigator&amp;s0=8&amp;pid=flyem_04male_082017&amp;sid0=kk_08_09_trans_pm_0_7_d11_1295&amp;zp=8&amp;yp=104236&amp;xp=115084" class="external-link" rel="nofollow">kk_08_09_trans_pm_0_7_d11_1295</ ...

# %%
page = confluence.get_page_by_title("ScientificComputing", "Scientific Computing Server - e06u05", start=None, limit=None, expand="metadata.labels,ancestors")
#page

# %%
# Wiki spaces to extract and save to files
spaces = ['SCSW','SCS','ScientificComputing']
limit = 50
num_pages = 0

for space in spaces:

    start = 0
    pages = []
    while True:
        pages_iter = confluence.get_all_pages_from_space(
            space, 
            start=start, 
            limit=limit, 
            expand="body.view,metadata.labels,ancestors,history.lastUpdated"
        )

        if len(pages_iter) == 0:
            break

        start += len(pages_iter)

        for page in pages_iter:
            page_id,path,title,body,labels,ancestors,authors = parse_page(page)
            
            # Skip archived pages
            if "ARCHIVE_SCSW" in ancestors: continue
            
            filepath = "../data/wiki/%s/%d" % (space,page_id)
            os.makedirs(os.path.dirname(filepath), exist_ok=True)
        
            with open(filepath, mode="wt") as f:
                f.write(get_link(path)+"\n")
                f.write(" / ".join(ancestors)+"\n")
                f.write(title+"\n")
                f.write(", ".join(authors)+"\n")
                f.write(", ".join(labels)+"\n")
                f.write(body)
                num_pages += 1
        
        # no more to fetch
        if len(pages_iter) < limit:
            break

    print('Found %d pages in %s' % (num_pages,space))
# Out:
# Found 182 pages in SCSW
# Found 224 pages in SCS
# Found 507 pages in ScientificComputing
